# %%
# %%HTML
# <link rel="stylesheet" type="text/css" href="css/sage_table_form.css">
# Out:
# <link rel="stylesheet" type="text/css" href="css/sage_table_form.css">

# %%
# python2.7カーネルでsageの関数を使う
# %load_ext sage
# jupyter用のdisplayメソッド
from IPython.display import display, Latex, HTML, Math, JSON
# テンプレートエンジン
load('script/JinjaMagics.py')
# ユーティリティ
load('script/sage_util.py')

# %%
x = var('x')
f = x^3 - x^2 - 2*x
f_plt = plot(f, [x, -2.5, 2.5], figsize=5)
Graphics2Html(f_plt)
# Out:
# <__main__.Graphics2Html instance at 0x7fac35a46248>

# %%
# (x0, y0)での接線を求める
x0 = var('x0')
y0 = f(x=x0)
f1 = diff(f, x)
Math(latex(f1))
# Out:
# $$3 \, x^{2} - 2 \, x - 2$$

# %%
# x0 = 0での接線の式
y = f1(x=x0)*(x - x0) + y0
Math(latex([y, y(x0 = 0)]))
# Out:
# $$\left[x_{0}^{3} + {\left(3 \, x_{0}^{2} - 2 \, x_{0} - 2\right)} {\left(x - x_{0}\right)} - x_{0}^{2} - 2 \, x_{0}, -2 \, x\right]$$

# %%
y_plt = plot(y(x0=0), [x, -2.5, 2.5], rgbcolor='green', figsize=5)
Graphics2Html(y_plt)
# Out:
# <__main__.Graphics2Html instance at 0x7fac35aeea28>

# %%
# x = 0のポイントをセット
pt = (0, f(x=0))
pt_plt = point(pt, rgbcolor='red', pointsize=30)

# %%
Graphics2Html((f_plt + y_plt + pt_plt))
# Out:
# <__main__.Graphics2Html instance at 0x7fac31347a28>

# %%
# 与えられたx座標でのfと接線のグラフを返す関数を定義
def _MyGraph(x1):
    y_plt = plot(y(x0=x1), [x, -2.5, 2.5], rgbcolor='green', figsize=5)
    pt = (x1, f(x=x1))    # x0, y0の座標をセット
    pt_plt = point(pt, rgbcolor='red', pointsize=30)
    return (f_plt + y_plt + pt_plt) # f_pltは先の結果を再利用

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
def f(x):
    return x

# %%
widgets.interact(f, x=10);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-cac276e084b7> in <module>()
# ----> 1 widgets.interact(f, x=Integer(10));
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/ipywidgets/widgets/interaction.pyc in interact(__interact_f, **kwargs)
#     316         #        ...
#     317         f = __interact_f
# --> 318         w = interactive(f, **kwargs)
#     319         try:
#     320             f.widget = w
#
# /usr/lib/sagemath/local/lib/python2.7/site-packages/ipywidgets/widgets/interaction.pyc in interactive(__interact_f, **kwargs)
#     194     getcallargs(f, **{n:v for n,v,_ in new_kwargs})
#     195     # Now build the widgets from the abbreviations.
# --> 196     kwargs_widgets.extend(_widgets_from_abbreviations(new_kwargs))
#     197
#     198     # This has to be done as an assignment, not using container.children.append,
#
# ...
